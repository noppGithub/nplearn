# %% [markdown]
# ## convenience function
# put them in first cells of note book
# - Add `autoreload` extension to the notebook
# - Set `autoreload` mode to 2:reload all modules before execute user code
# - Plot matplotlib in the line of notebook

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %% [markdown]
# ## get function detail or even source code

# %%
#this is a function
display
# Out:
# <function IPython.core.display.display(*objs, include=None, exclude=None, metadata=None, transient=None, display_id=None, **kwargs)>

# %%
#this is how to get detail
# ?display

# %%
#this is how to get sourcecode
??display

# %% [markdown]
# ## [Shift] + [Tab] to get same information as above

# %% [markdown]
# ## Shell command + Python
# - Try `!ls` or something if using Linux
# - This help you to create complex shell command function with Python as helper

# %%
# !dir
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is DE0E-1719
#
#  Directory of D:\np\npds\learning_material\01_tools\01_Jupyter notebook
#
# 06/06/2019  10:32 AM    <DIR>          .
# 06/06/2019  10:32 AM    <DIR>          ..
# 06/06/2019  10:20 AM    <DIR>          .ipynb_checkpoints
# 06/06/2019  10:32 AM             2,585 Untitled.ipynb
#                1 File(s)          2,585 bytes
#                3 Dir(s)  21,808,099,328 bytes free

# %%
name = 'Dew'

# %%
# !echo {name}
# Out:
# Dew

# %%
f'My name is {name}'
# Out:
# 'My name is Dew'

# %%
# import some your custom module Python file
import sys
my_module_path = './a_custom_module/sub-directory/'
sys.path.append(my_module_path)

# %%
from a_custom_module import credentials as cfg

# %%
cfg['powerbi_access']
# Out:
# [{'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'SVP Saraburi Operations',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Sompoch Yathikul',
#   'Personnel Number': 13700001,
#   'Position': 'Department Manager - SVP SRB Operations',
#   'Sub Function': '-',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'SVP Saraburi Operations',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Kettipol Santakul',
#   'Personnel Number': 14700045,
#   'Position': 'Department Manager - SVP SRB Operations',
#   'Sub Function': '-',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Operations',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Bandhit Ngarmkum',
#   'Personnel Number': 13100011,
#   'Position': 'Senior Manager - Operations',
#   'Sub Function': 'Operations',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Plant 1',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Prakasit Suwannajata',
#   'Personnel Number': 13100013,
#   'Position': 'Plant 1 Manager',
#   'Sub Function': 'Operations',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Plant 1',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Somyot Niyomchon',
#   'Personnel Number': 13100010,
#   'Position': 'Deputy Plant Manager of Production',
#   'Sub Function': 'Operations',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Plant 2',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Sarit Sangon',
#   'Personnel Number': 14800038,
#   'Position': 'Plant2 Manager',
#   'Sub Function': 'Operations',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Plant 2',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Suchart Kongchanpat',
#   'Personnel Number': 13700059,
#   'Position': 'Deputy Plant 2 Manager',
#   'Sub Function': 'Operations',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Plant 3',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Wasan Amitsoon',
#   'Personnel Number': 13600064,
#   'Position': 'Plant 3 Manager',
#   'Sub Function': 'Operations',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Plant 3',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Wiwat Patanavirod',
#   'Personnel Number': 13300117,
#   'Position': 'Deputy Plant 3 Manager',
#   'Sub Function': 'Operations',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Quarry',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Songkran Onkamleaung',
#   'Personnel Number': 13300138,
#   'Position': 'Quarry Department Manager',
#   'Sub Function': 'Operations',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Community Relations',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Sunan Samrianram',
#   'Personnel Number': 15500028,
#   'Position': 'Community Relations Department Manager',
#   'Sub Function': '-',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Environment & Standard System',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Miss Sawitri Phatayanon',
#   'Personnel Number': 14700041,
#   'Position': 'Environment and Standard Systems Department Manager',
#   'Sub Function': '-',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Occupational Health, Safety and Security',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Chawin Chaitaimwong',
#   'Personnel Number': 14900002,
#   'Position': 'OHS&S Department Manager',
#   'Sub Function': '-',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': '-',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Sawai Panma',
#   'Personnel Number': 12800006,
#   'Position': 'Senior Manager Maintenance & Reliability',
#   'Sub Function': 'Maintenance & Reliability',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Mechanical Maintenance',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Teerapong Sornklin',
#   'Personnel Number': 13400051,
#   'Position': 'Mechanical Maintenance Department Manager',
#   'Sub Function': 'Maintenance & Reliability',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Reliability Management',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Chutidej Phongsai',
#   'Personnel Number': 14800047,
#   'Position': 'Reliability Management Department Manager',
#   'Sub Function': 'Maintenance & Reliability',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Electrical Maintenance and Digital',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Chaiyan Sakulsaowapakkul',
#   'Personnel Number': 14900008,
#   'Position': 'Electrical Maintenance and Digital Department Manager',
#   'Sub Function': 'Maintenance & Reliability',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Technical Capabilities Development',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Damrongsak Pasuwan',
#   'Personnel Number': 14500003,
#   'Position': 'Senior Manager Technical Capabilities Development',
#   'Sub Function': 'Digital & Functional Excellence',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Technical Development Center and Coach',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Suwit Pinwanichkul',
#   'Personnel Number': 13300066,
#   'Position': 'Technical Development Center and Coach Department Manager',
#   'Sub Function': 'Digital & Functional Excellence',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Process Engineering and Digital Coordination',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Nuntachai Srinapawong',
#   'Personnel Number': 14400023,
#   'Position': 'Process Engineering Deparment Manager',
#   'Sub Function': 'Digital & Functional Excellence',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Quality and Product Development',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Sompon Chanvaivit',
#   'Personnel Number': 12800002,
#   'Position': 'Quality and Product Development Department Manager',
#   'Sub Function': 'Digital & Functional Excellence',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Strategic Supply Chain and Operation',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mrs. Chanadda Phongsai',
#   'Personnel Number': 14900088,
#   'Position': 'Stratagic Supply Chain and Operation Department Manager',
#   'Sub Function': 'Digital & Functional Excellence',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Geology',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Waiwit Naraballobh',
#   'Personnel Number': 14700035,
#   'Position': 'Geology Department Manager',
#   'Sub Function': 'Digital & Functional Excellence',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Geology',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Sa-Nguan Choochang',
#   'Personnel Number': 14700067,
#   'Position': 'Geology Department Manager',
#   'Sub Function': 'Digital & Functional Excellence',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Plant Logistics',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Wisun Paritatpisal',
#   'Personnel Number': 13400059,
#   'Position': 'Senior Manager Plant Logisitics',
#   'Sub Function': 'Plant Logistics',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Plant Logistics Operation Control',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Siri Amraram',
#   'Personnel Number': 13700066,
#   'Position': 'Plant Logistics Operation Control Department Manager',
#   'Sub Function': 'Plant Logistics',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Cement Packing',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Nakorn Ittipunkul',
#   'Personnel Number': 13400079,
#   'Position': 'Cement Packing Department Manager',
#   'Sub Function': 'Plant Logistics',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Plant Logistics Development and Reliability',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Taweesak Nawawitrattana',
#   'Personnel Number': 13300068,
#   'Position': 'Plant Logistics Development and Reliability Department Manager',
#   'Sub Function': 'Plant Logistics',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Projects and Engineering',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Prapan Sindhurattavej',
#   'Personnel Number': 12800003,
#   'Position': 'Senior Manager Projects and Engineering',
#   'Sub Function': 'Projects and Engineering',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Projects and Engineering',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Sumrit Chanaphan',
#   'Personnel Number': 13500007,
#   'Position': 'Project Manager',
#   'Sub Function': 'Projects and Engineering',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Projects and Engineering',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Akapon Tasanaset',
#   'Personnel Number': 14800041,
#   'Position': 'Project Manager / Project Support and Information Division Manger [Acting]',
#   'Sub Function': 'Projects and Engineering',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Infrastructure Management Department',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Narongrat Taugchunta',
#   'Personnel Number': 13000025,
#   'Position': 'Infrastructure Management Department Manager',
#   'Sub Function': 'Projects and Engineering',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'CAPEX Project Management',
#   'Function': 'SVP Saraburi Operations',
#   'Name of Employee': 'Mr. Weera Ploypai',
#   'Personnel Number': 13200014,
#   'Position': 'CAPEX Project Management Department Manager',
#   'Sub Function': 'Projects and Engineering',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Power Company Limited',
#   'Department': 'Operations',
#   'Function': 'Siam City Power Company Limited',
#   'Name of Employee': 'Mr. Somboon Suksombatcharoen',
#   'Personnel Number': 13700054,
#   'Position': 'Operation Department Manager',
#   'Sub Function': '-',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': '-',
#   'Function': '-',
#   'Name of Employee': 'Mr. Aidan John Lynam',
#   'Personnel Number': 16200078,
#   'Position': 'Group Chief Executive Officer',
#   'Sub Function': '-',
#   'mgt_level': 'NO MANAGEMENT LEVEL'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': '-',
#   'Function': '-',
#   'Name of Employee': 'Mr. Mark Anatol Schmidt',
#   'Personnel Number': 16200096,
#   'Position': 'Group Chief Financial Officer / SVP Finance and Controlling',
#   'Sub Function': '-',
#   'mgt_level': 'TML-EXCO'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': '-',
#   'Function': '-',
#   'Name of Employee': 'Miss Panittra Silanon',
#   'Personnel Number': 14900080,
#   'Position': 'Head of Group Business Planning, Transformation and Performance / Head of Group Procurement / Chief Transformation Officer (CTO)',
#   'Sub Function': '-',
#   'mgt_level': 'TML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'CEO  Office',
#   'Function': 'CEO  Office',
#   'Name of Employee': 'Mr. Siva Mahasandana',
#   'Personnel Number': 13200010,
#   'Position': 'Chief Executive Officer / SVP (Saraburi Operation) / Chief Executive Officer',
#   'Sub Function': '-',
#   'mgt_level': 'TML-EXCO'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'SVP People & Organizational Performance',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Miss Anuttara Panpothong',
#   'Personnel Number': 16000112,
#   'Position': 'SVP P&OP',
#   'Sub Function': '-',
#   'mgt_level': 'TML-EXCO'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': '-',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Miss Somruethai Rattanamanee',
#   'Personnel Number': 16100002,
#   'Position': 'Head of Service Excellence / Head of Business Partner - Siam City Concrete [Acting]',
#   'Sub Function': 'Service Excellence',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'P&OP Services Center',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Miss Wattana Lawsakornchai',
#   'Personnel Number': 14200006,
#   'Position': 'P&OP Services Center Department Manager',
#   'Sub Function': 'Service Excellence',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'P&OP Services Center',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Miss Prattana Jinnathampong',
#   'Personnel Number': 16100142,
#   'Position': 'P&OP Division Manager (Payroll Operations)',
#   'Sub Function': 'Service Excellence',
#   'mgt_level': 'MML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'P&OP Services Center',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'MR. Taweechai Ratinunchaporn',
#   'Personnel Number': 16100143,
#   'Position': 'Senior P&OP Officer (Payroll Operations)',
#   'Sub Function': 'Service Excellence',
#   'mgt_level': 'FML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'P&OP Services Center',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Miss Panisa Wattanakitjakul',
#   'Personnel Number': 16100224,
#   'Position': 'Senior P&OP Officer (Payroll Operations)',
#   'Sub Function': 'Service Excellence',
#   'mgt_level': 'FML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Human Resources Information System',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Mr. Thara Kinchagawat',
#   'Personnel Number': 16100250,
#   'Position': 'Human Resources Information System Department Manager',
#   'Sub Function': 'Service Excellence',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Human Resources Information System',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Miss Piyawan Pattarapisarnkun',
#   'Personnel Number': 16100223,
#   'Position': 'Senior P&OP Executive (Human Resource Information System)',
#   'Sub Function': 'Service Excellence',
#   'mgt_level': 'MML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Human Resources Information System',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Miss Saranan Khotthamat',
#   'Personnel Number': 16100030,
#   'Position': 'P&OP Executive (Human Resource Information System)',
#   'Sub Function': 'Service Excellence',
#   'mgt_level': 'FML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Human Resources Information System',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Mr. Kasin Jarutekumporn',
#   'Personnel Number': 16200269,
#   'Position': 'P&OP Executive (Human Resource Application)',
#   'Sub Function': 'Service Excellence',
#   'mgt_level': 'FML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Human Resources Information System',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Mr. Weerapol Changyou',
#   'Personnel Number': 15300002,
#   'Position': 'Senior P&OP Officer (HR Application)',
#   'Sub Function': 'Service Excellence',
#   'mgt_level': 'FML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Organization Effectiveness',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Mr. Akaraphol Weerawong',
#   'Personnel Number': 16200066,
#   'Position': 'Head of Organization Effectiveness',
#   'Sub Function': '-',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Business Partner - Saraburi Operations',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Mr. Natthakit Kimsritun',
#   'Personnel Number': 16100277,
#   'Position': 'Head of Business Partner - Saraburi Operations',
#   'Sub Function': '-',
#   'mgt_level': 'SML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Business Partner - Saraburi Operations',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Miss Patcharin Promsamut',
#   'Personnel Number': 16100225,
#   'Position': 'P&OP Division Manager (Business Partner)',
#   'Sub Function': '-',
#   'mgt_level': 'MML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Business Partner - Saraburi Operations',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Miss Nabhathra Manorom',
#   'Personnel Number': 14600012,
#   'Position': 'P&OP Division Manager (Business Partner)',
#   'Sub Function': '-',
#   'mgt_level': 'MML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Business Partner - Saraburi Operations',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Miss Chanyapan Chaosittichai',
#   'Personnel Number': 16100145,
#   'Position': 'Senior P&OP Business Partner',
#   'Sub Function': '-',
#   'mgt_level': 'MML'},
#  {'Company': 'Siam City Cement Public Company Limited',
#   'Department': 'Business Partner - Saraburi Operations',
#   'Function': 'SVP People & Organizational Performance',
#   'Name of Employee': 'Mr. Pasakorn Akranikul',
#   'Personnel Number': 16100237,
#   'Position': 'Senior P&OP Executive (Talent Acquisition)',
#   'Sub Function': '-',
#   'mgt_level': 'MML'}]
